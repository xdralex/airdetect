# %%
import os
import yaml
import torch

from airdetect.aircraft_detector import visualize_stored_predictions

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.ion()

# %%
with open('../config.yaml', 'r') as config_file:
    config = yaml.load(config_file, Loader=yaml.Loader)

# %%
dataset = 'reallife'

visualize_stored_predictions(dataset_config=config['datasets'][dataset],
                             bboxes_path=config['boost']['bboxes'][dataset],
                             samples=10,
                             directory='/data/ssd/run/airdetect/debug')
