# %%
# %load_ext tensorboard

# %%
# !kill 5042

# %%
# %tensorboard --bind_all --port 6006 --logdir /home/apollo/package/data/ssd/run/airlinersnet/tensorboard
# Out:
#       <iframe id="tensorboard-frame-4971a09c9e8d52cf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4971a09c9e8d52cf");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
